# %% [markdown]
# # Pandas - 데이터 조작

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - 데이터 읽고

# %%
cctv = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv', skiprows=1, encoding='euc-kr')

# %% [markdown]
# - 데이터 탐색을 위한 메소드

# %%
cctv.head()
# 앞에서 다섯줄만 표시(데이터 모양을 볼 수)
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
cctv.tail(3)
# 밑에서부터 표시 
# 기본 5, ()에 원하는 수량을 설정
# Out:
#      구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 23  강남구  6,502      124    77    75   597   840  1310   999   748   789   942
# 24  송파구  2,854       72    61    86    85   215   148   241   542  1068   235
# 25  강동구  2,547      332    27   163    49   154   202   273   377   356   614
#
#    2021년
# 23     1
# 24   101
# 25     0

# %%
cctv.info()

# object : string(천단위 구분기호 때문 )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        26 non-null     object
#  1   총계        26 non-null     object
#  2   2012년 이전  26 non-null     object
#  3   2012년     26 non-null     object
#  4   2013년     26 non-null     object
#  5   2014년     26 non-null     object
#  6   2015년     26 non-null     object
#  7   2016년     26 non-null     object
#  8   2017년     26 non-null     object
#  9   2018년     26 non-null     object
#  10  2019년     26 non-null     object
#  11  2020년     26 non-null     object
#  12  2021년     26 non-null     object
# dtypes: object(13)
# memory usage: 2.8+ KB

# %%
df= pd.DataFrame(np.random.randint(40,101,20).reshape(4,5),
                columns=list('ABCDE'),index=list('wxyz'))
df
# Out:
#     A   B   C   D   E
# w  94  82  66  57  51
# x  57  90  63  93  41
# y  92  95  87  74  71
# z  60  90  87  98  56

# %%
df.info()
#int 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, w to z
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int32
#  1   B       4 non-null      int32
#  2   C       4 non-null      int32
#  3   D       4 non-null      int32
#  4   E       4 non-null      int32
# dtypes: int32(5)
# memory usage: 112.0+ bytes

# %%
# 컬럼별로 / 기초통계자료 
df.describe()
# Out:
#                A          B          C          D      E
# count   4.000000   4.000000   4.000000   4.000000   4.00
# mean   75.750000  89.250000  75.750000  80.500000  54.75
# std    19.972898   5.377422  13.047988  18.770544  12.50
# min    57.000000  82.000000  63.000000  57.000000  41.00
# 25%    59.250000  88.000000  65.250000  69.750000  48.50
# 50%    76.000000  90.000000  76.500000  83.500000  53.50
# 75%    92.500000  91.250000  87.000000  94.250000  59.75
# max    94.000000  95.000000  87.000000  98.000000  71.00

# %%
df
# Out:
#     A   B   C   D   E
# w  94  82  66  57  51
# x  57  90  63  93  41
# y  92  95  87  74  71
# z  60  90  87  98  56

# %%
df.sum()     # axis =0가 기본값
# Out:
# A    303
# B    357
# C    303
# D    322
# E    219
# dtype: int64

# %%
# 행 기준 하고싶다면 

df.sum(axis=1)
# Out:
# w    350
# x    344
# y    419
# z    391
# dtype: int64

# %%
df.std(axis=1)
# Out:
# w    17.790447
# x    22.253090
# y    10.756393
# z    18.926172
# dtype: float64

# %%
df.mean().round(2)
# 소수점 제한 
# round : 소수점 둘째자리까지
# Out:
# A    75.75
# B    89.25
# C    75.75
# D    80.50
# E    54.75
# dtype: float64

# %%
df.quantile(0.25,axis=1)    # 4분위수

# 넘파이와 다름(quatile/quantile)
# Out:
# w    57.0
# x    57.0
# y    74.0
# z    60.0
# Name: 0.25, dtype: float64

# %% [markdown]
# - 결측치 처리

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()

# 타이타닉 탑승자 데이터 앞 5개
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()

# 891이 대부분인데 그보다 작은 데이터는 나머지가 결측치 (age.deck..)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# age 결측치는 age 열의 평균으로 대체 
titanic['age'].fillna(titanic.age.mean(), inplace=True)
titanic.tail(3)

# 비교하기
# Out:
#      survived  pclass     sex        age  sibsp  parch   fare embarked  class  \
# 888         0       3  female  29.699118      1      2  23.45        S  Third
# 889         1       1    male  26.000000      0      0  30.00        C  First
# 890         0       3    male  32.000000      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# embarked 결측치는 행 삭제 (subset=)
titanic.dropna(subset=['embarked'], inplace=True)
titanic.dropna(subset=['embark_town'], inplace=True)
titanic.tail()
# Out:
#      survived  pclass     sex        age  sibsp  parch   fare embarked  \
# 886         0       2    male  27.000000      0      0  13.00        S
# 887         1       1  female  19.000000      0      0  30.00        S
# 888         0       3  female  29.699118      1      2  23.45        S
# 889         1       1    male  26.000000      0      0  30.00        C
# 890         0       3    male  32.000000      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True

# %%
# deck 컬럼은 컬럼 삭제 (columns=)
# 결측치가 너무 많아서 deck 자체를 날리므로 drop 
titanic.drop(columns=['deck'],inplace=True)

# %%
titanic.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# - apply ( list의 map)
# - 특정 행/열에 함수를 적용

# %% [markdown]
# - 시리즈에 apply : 람다의 x 는 시리즈의 모든 열 (맞냐..)

# %% [markdown]
# - lambda 함수 : 함수를 한 줄로 표현할 수 O
# - 형태 = lambda 인자 : 표현식

# %%
df
# Out:
#     A   B   C   D   E
# w  94  82  66  57  51
# x  57  90  63  93  41
# y  92  95  87  74  71
# z  60  90  87  98  56

# %%
# 각 열의 최댓값과 최소값의 차이 
df.apply(lambda x : x.max() - x.min()) # apply 기본은 axis=0

# 데프 전체 / 특정 둘다 적용 
# (함수)
# Out:
# A    37
# B    13
# C    24
# D    41
# E    30
# dtype: int64

# %%
# 각 행의 최댓값-최솟값 차이 
df.apply(lambda x : x.max() - x.min(), axis=1)
# Out:
# w    43
# x    52
# y    24
# z    42
# dtype: int64

# %%
# 타이타닉 승객 중 20세 넘으면 'adult' , 그렇지 않으면 'child'
titanic['adult/child'] = titanic.age.apply(lambda x : 'adult' if x > 20 else 'child') 
titanic.tail()

# 람다는 한 문장만 작성 
# if 작성하고 싶으면 삼항연산자
# Out:
#      survived  pclass     sex        age  sibsp  parch   fare embarked  \
# 886         0       2    male  27.000000      0      0  13.00        S
# 887         1       1  female  19.000000      0      0  30.00        S
# 888         0       3  female  29.699118      1      2  23.45        S
# 889         1       1    male  26.000000      0      0  30.00        C
# 890         0       3    male  32.000000      0      0   7.75        Q
#
#       class    who  adult_male  embark_town alive  alone adult/child
# 886  Second    man        True  Southampton    no   True       adult
# 887   First  woman       False  Southampton   yes   True       child
# 888   Third  woman       False  Southampton    no  False       adult
# 889   First    man        True    Cherbourg   yes   True       adult
# 890   Third    man        True   Queenstown    no   True       adult

# %%
# cctv 소숫점 없애기 

cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
# 총계 연습


cctv['총계'] = cctv['총계'].apply(lambda x : int(x.replace(',','')))       # ,를 먼저 떼주고 정수변환(int) 순서** 
cctv.head()
# Out:
#     구분     총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1772      813      0      0    210    150      1    261     85
# 2  중 구   2333       16    114     87     77    236    240    372    386
# 3  용산구   2383       34     71    234    125    221    298    351    125
# 4  성동구   3602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
# 그럼 원하는 범위를 하고 싶을 때는(2012년 이전~ 끝)

# %%
cctv.columns        
# 리스트 형태로 출력됨 
# 바꾸고 싶은 건 2012년 이전(인덱스 값 2~ ) - 
# 리스트니까 슬라이스
# Out:
# Index(['구분', '총계', '2012년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년', '2019년', '2020년', '2021년'],
#       dtype='object')

# %%
for column in cctv.columns[2:]:
    cctv[column] = cctv[column].apply(lambda x : int(x.replace(',','')))
cctv.head(3)
# Out:
#     구분     총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77032      7667   2200   3491   4439   6582   8129   9947   9876
# 1  종로구   1772       813      0      0    210    150      1    261     85
# 2  중 구   2333        16    114     87     77    236    240    372    386
#
#    2019년  2020년  2021년
# 0  11961  11132   1608
# 1      9    200     43
# 2    155    361    289
